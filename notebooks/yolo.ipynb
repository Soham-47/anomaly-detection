# %%
# !ls

# %%
# !ls /kaggle/input
# Out:
# datasets

# %%
pip install ultralytics
# Out:
# Running cells with '.venv (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/soham/Downloads/anomaly-detection/anomaly-detection/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
# !find /kaggle/input -maxdepth 3 -type d
# Out:
# /kaggle/input
# /kaggle/input/datasets
# /kaggle/input/datasets/aliabdelmenam
# /kaggle/input/datasets/aliabdelmenam/rdd-2022

# %%
# %%writefile /kaggle/working/data.yaml
#
# # Path to dataset root
# path: /kaggle/input/datasets/aliabdelmenam/rdd-2022/RDD_SPLIT
#
#
# # Train, val, test sets
# train: train/images
# val: val/images
# test: test/images
#
# # Number of classes
# nc: 7
#
# # Class names
# names:
#   0: alligator_crack
#   1: block_crack
#   2: longitudinal_crack
#   3: other_corruption
#   4: pothole
#   5: repair
#   6: transverse_crack
# Out:
# Writing /kaggle/working/data.yaml

# %%
# %%writefile /kaggle/working/hyp.yaml
#
# epochs: 70
# imgsz: 640
# batch: 16
# optimizer: MuSGD
# lr0: 0.01
# mosaic: 1.0
# copy_paste: 0.2
# cls: 0.7
# patience: 30
# Out:
# Writing /kaggle/working/hyp.yaml

# %%
from ultralytics import YOLO

model = YOLO("/kaggle/input/datasets/sohamgawd47foden/best-model/best (1).pt")

# %%
model.train(data="data.yaml", cfg="hyp.yaml", device=0, amp=True)
model.val(data="data.yaml", augment=True)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 14913MiB)
# ...
